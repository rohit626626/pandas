# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
df
# Out:
#          SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0     20MICRONS     EQ   27-Aug-2020       32.90       33.10       34.00
# 1    21STCENMGM     EQ   27-Aug-2020       10.40       10.40       10.60
# 2    3IINFOTECH     EQ   27-Aug-2020        3.95        4.10        4.10
# 3       3MINDIA     EQ   27-Aug-2020    20866.15    21100.00    21510.05
# 4        5PAISA     BE   27-Aug-2020      353.70      355.00      364.90
# ..          ...    ...           ...         ...         ...         ...
# 549   GEOJITFSL     EQ   27-Aug-2020       41.15       41.15       41.40
# 550       GEPIL     EQ   27-Aug-2020      492.40      494.90      498.90
# 551      GESHIP     EQ   27-Aug-2020      273.00      275.00      283.00
# 552       GET&D     EQ   27-Aug-2020      111.45      113.75      113.75
# 553  GFLLIMITED     EQ   27-Aug-2020      103.05      104.95      104.95
#
#      LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...

# %%
df.head() #axis by default top 5 row
# Out:
#        SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0   20MICRONS     EQ   27-Aug-2020       32.90        33.1       34.00
# 1  21STCENMGM     EQ   27-Aug-2020       10.40        10.4       10.60
# 2  3IINFOTECH     EQ   27-Aug-2020        3.95         4.1        4.10
# 3     3MINDIA     EQ   27-Aug-2020    20866.15     21100.0    21510.05
# 4      5PAISA     BE   27-Aug-2020      353.70       355.0      364.90
#
#    LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0      33.00       33.45        33.25      33.39        154505          51.59
# 1      10.25       10.55        10.55      10.41          6019           0.63
# 2       3.90        4.00         4.05       4.04      12684409         512.28
# 3   20866.15    20970.45     20999.80   21219.66          6262        1328.78
# 4     350.00      361.00       361.40     362.32         14947          54.16
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# ...

# %%
df.head(3) #axis  top 3 row
# Out:
#        SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0   20MICRONS     EQ   27-Aug-2020       32.90        33.1        34.0
# 1  21STCENMGM     EQ   27-Aug-2020       10.40        10.4        10.6
# 2  3IINFOTECH     EQ   27-Aug-2020        3.95         4.1         4.1
#
#    LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0      33.00       33.45        33.25      33.39        154505          51.59
# 1      10.25       10.55        10.55      10.41          6019           0.63
# 2       3.90        4.00         4.05       4.04      12684409         512.28
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# 0          1130    116799      75.6
# 1            35      5235     86.97
# 2          5251   7334888     57.83

# %%
df.tail() #axis by default bottom 5 row
# Out:
#          SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 549   GEOJITFSL     EQ   27-Aug-2020       41.15       41.15       41.40
# 550       GEPIL     EQ   27-Aug-2020      492.40      494.90      498.90
# 551      GESHIP     EQ   27-Aug-2020      273.00      275.00      283.00
# 552       GET&D     EQ   27-Aug-2020      111.45      113.75      113.75
# 553  GFLLIMITED     EQ   27-Aug-2020      103.05      104.95      104.95
#
#      LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# 549      39.50       40.65        40.15      40.52        254849
# 550     490.80      493.90       491.70     493.65         23561
# 551     273.15      277.60       277.35     279.04        185610
# 552     108.55      111.85       110.35     111.03         54113
# 553     100.00      101.20       100.95     102.80         89738
#
#      TURNOVER_LACS  NO_OF_TRADES DELIV_QTY DELIV_PER
# 549         103.27          2846    178837     70.17
# ...

# %%
df.tail(3) #axis bottom 3 row
# Out:
#          SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 551      GESHIP     EQ   27-Aug-2020      273.00      275.00      283.00
# 552       GET&D     EQ   27-Aug-2020      111.45      113.75      113.75
# 553  GFLLIMITED     EQ   27-Aug-2020      103.05      104.95      104.95
#
#      LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# 551     273.15      277.60       277.35     279.04        185610
# 552     108.55      111.85       110.35     111.03         54113
# 553     100.00      101.20       100.95     102.80         89738
#
#      TURNOVER_LACS  NO_OF_TRADES DELIV_QTY DELIV_PER
# 551         517.92          4637     74049     39.89
# 552          60.08          1192     33990     62.81
# 553          92.25          1825     54348     60.56

# %%
df=pd.read_csv("data.csv", dtype={"TTL_TRD_QNTY":"float64", "NO_OF_TRADES":"float64"}) #change columns data type
df
# Out:
#          SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0     20MICRONS     EQ   27-Aug-2020       32.90       33.10       34.00
# 1    21STCENMGM     EQ   27-Aug-2020       10.40       10.40       10.60
# 2    3IINFOTECH     EQ   27-Aug-2020        3.95        4.10        4.10
# 3       3MINDIA     EQ   27-Aug-2020    20866.15    21100.00    21510.05
# 4        5PAISA     BE   27-Aug-2020      353.70      355.00      364.90
# ..          ...    ...           ...         ...         ...         ...
# 549   GEOJITFSL     EQ   27-Aug-2020       41.15       41.15       41.40
# 550       GEPIL     EQ   27-Aug-2020      492.40      494.90      498.90
# 551      GESHIP     EQ   27-Aug-2020      273.00      275.00      283.00
# 552       GET&D     EQ   27-Aug-2020      111.45      113.75      113.75
# 553  GFLLIMITED     EQ   27-Aug-2020      103.05      104.95      104.95
#
#      LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...

# %%
# df=pd.read_csv("data.csv", true_values=["Yes"], false_values=["No"]) #convert Yes value into True and No value in into False
